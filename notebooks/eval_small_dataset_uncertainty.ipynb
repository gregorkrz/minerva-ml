# %%
from pathlib import Path
from eval_E_available_plots import load_eval_data_grouped, plot_rms_iqr_with_uncertainty

CKPT_DIR = Path("/global/cfs/cdirs/m3246/gregork/checkpoints")

BASELINE_RUN = "E_avail_no_muon_Log1pMSE_20260228_024020"

# Structure: loss -> "Architecture N_samples" -> [run_seed_1, run_seed_2, ...]
training_names_grouped = {"Log1p": {}}

training_names_grouped["Log1p"]["Transformer 6M"] = [
    "E_avail_no_muon_Log1pMSE_20260228_024020",
    "E_avail_Log1PLoss_20260228_155407",
]

#training_names_grouped["Log1p"]["Transformer 2M"] = [
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_42_20260227_204429",
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_43_20260227_205634",
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_44_20260227_205634",
#]

#training_names_grouped["Log1p"]["Transformer 1M"] = [
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_42_20260227_203125",
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_43_20260227_203126",
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_44_20260227_204430",
#]

training_names_grouped["Log1p"]["Transformer 500k"] = [
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516",
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619",
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846",
]

training_names_grouped["Log1p"]["Transformer 100k"] = [
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544",
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544",
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426",
]

data = load_eval_data_grouped(CKPT_DIR, training_names_grouped, baseline_run=BASELINE_RUN)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1PLoss_20260228_155407 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426 on playlist 1A

# %%
sample_colors = {
    "6M":   "#1b9e77",
    "2M":   "#d95f02",
    "1M":   "#7570b3",
    "500k": "#e7298a",
    "100k": "#66a61e",
}

fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=training_names_grouped,
    baseline_run=BASELINE_RUN,
    colors=sample_colors,
    data=data,
)

# %%
training_names_omni_list = """OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260301_012544
OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_012542
OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260301_012544
OmniM_SmallDataset_E_avail_Log1PLoss_PT_1A_20260301_012544
OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260301_012539
SmallDataset_E_avail_Log1PLoss_dscap2000000_Evts_seed_42_1A_20260228_151917
SmallDataset_E_avail_Log1PLoss_PT_1A_20260228_151917
SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260228_151916
SmallDataset_E_avail_Log1PLoss_dscap1000000_Evts_seed_42_1A_20260228_151916
SmallDataset_E_avail_Log1PLoss_1A_20260228_151917
SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260228_151911
SmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_42_1A_20260228_151910
SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260228_151908
SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260228_151913
SmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260228_151913"""

traning_names_grouped_omni = {"Log1p": {}}

# OmniLearned pretrained
traning_names_grouped_omni["Log1p"]["OmniM PT 6M"] = [
    "OmniM_SmallDataset_E_avail_Log1PLoss_PT_1A_20260301_012544",
]
traning_names_grouped_omni["Log1p"]["OmniM PT 2M"] = [
    "OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260301_012544",
]
traning_names_grouped_omni["Log1p"]["OmniM PT 1M"] = [
    "OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260301_012544",
]
traning_names_grouped_omni["Log1p"]["OmniM PT 500k"] = [
    "OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_012542",
]
traning_names_grouped_omni["Log1p"]["OmniM PT 100k"] = [
    "OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260301_012539",
]

# Transformer (no pretraining)
traning_names_grouped_omni["Log1p"]["OmniS 6M"] = [
    "SmallDataset_E_avail_Log1PLoss_1A_20260228_151917",
]
traning_names_grouped_omni["Log1p"]["OmniS 2M"] = [
    "SmallDataset_E_avail_Log1PLoss_dscap2000000_Evts_seed_42_1A_20260228_151917",
]
traning_names_grouped_omni["Log1p"]["OmniS 1M"] = [
    "SmallDataset_E_avail_Log1PLoss_dscap1000000_Evts_seed_42_1A_20260228_151916",
]
traning_names_grouped_omni["Log1p"]["OmniS 500k"] = [
    "SmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260228_151913",
]
traning_names_grouped_omni["Log1p"]["OmniS 100k"] = [
    "SmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_42_1A_20260228_151910",
]

# Transformer pretrained
traning_names_grouped_omni["Log1p"]["OmniS PT 6M"] = [
    "SmallDataset_E_avail_Log1PLoss_PT_1A_20260228_151917",
]
traning_names_grouped_omni["Log1p"]["OmniS PT 2M"] = [
    "SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260228_151916",
]
traning_names_grouped_omni["Log1p"]["OmniS PT 1M"] = [
    "SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260228_151913",
]
traning_names_grouped_omni["Log1p"]["OmniS PT 500k"] = [
    "SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260228_151911",
]
traning_names_grouped_omni["Log1p"]["OmniS PT 100k"] = [
    "SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260228_151908",
]

# %%
# plot here 
import numpy as np
fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=traning_names_grouped_omni,
    baseline_run=BASELINE_RUN,
    colors=sample_colors,
    transform=lambda x: np.exp(x)-1
)
# Out:
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_012542 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260301_012539 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap2000000_Evts_seed_42_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap1000000_Evts_seed_42_1A_20260228_151916 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260228_151913 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_42_1A_20260228_151910 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260228_151916 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260228_151913 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260228_151911 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260228_151908 on 1A
# Transforming the prediction
# E pred dict first 10 entries [ 2.1328917  1.2252753  1.4389567  0.8112726  0.768064  12.049016
#   2.7610075  2.6807294  0.3431723  0.9490807]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 51.366745
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.3511035   1.0964575   1.3131516   0.908316    0.75226104 12.00809
#   2.487356    2.2327569   0.32292533  0.93903124]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 6.234646e-05 47.767506
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.0749772   1.2362616   1.2929132   0.9312196   0.920097   10.852761
#   2.9278753   2.3231435   0.3040563   0.83571434]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 47.944263
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.2401872  1.2766871  1.4303708  1.2812648  1.0171349  9.127891
#  2.5055733  3.8491268  0.38534713 0.7528515 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.006026149 49.40815
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.2096198  1.1689022  1.1851327  1.2421024  0.52690566 7.82145
#  3.2694912  3.3903503  0.38097286 0.7133416 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 48.271523
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 1.7786846   2.1461878   1.1391027   0.93181336  0.6962347  10.313893
#   2.86879     3.2596216   0.33482647  0.9334216 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 172.38914
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.0479739   1.5998173   1.2019327   0.8768368   0.68222785 10.273436
#   2.3599901   2.9826317   0.32851708  1.0775006 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 50.082443
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.1456656   1.6178453   1.261414    1.1493087   0.82157385 10.040642
#   2.5934463   3.0856729   0.31516957  0.8943478 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 46.293064
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 1.927165    1.0024765   1.253555    1.5264876   0.80272365 10.274354
#   2.8856573   2.7266316   0.36904597  0.74590147]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 60.929173
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.0720725 1.0776412 1.3463356 1.2398701 0.5884998 9.029324  2.7340324
#  4.3877087 0.4247924 0.9461025]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 51.264782
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.1457322   1.3571007   1.5149496   1.0836961   0.5743786  12.544759
#   2.7743068   3.398192    0.34493637  0.93906593]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.025932074 50.814632
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.1421306  1.1283238  1.2064312  1.0529354  0.70877445 9.267948
#  2.440315   3.186335   0.34490383 1.0938616 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 48.60999
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.167749    1.2610009   1.2917881   1.1010957   0.68354666 10.025343
#   2.633827    2.6782598   0.30769563  0.95099306]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.04857397 48.967957
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.307078    1.365999    1.353472    1.2585714   0.7005459  10.151405
#   2.5349414   3.0537114   0.41356587  0.9122894 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.029037595 48.18522
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [1.6771727  1.5492458  1.3677659  1.0949624  0.7900934  7.2600317
#  2.680091   5.1212316  0.38108099 0.8320092 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 62.179977
# E true dict min max 0.0 77.44185

# %%
from eval_E_available_plots import plot_residuals_by_energy, flatten_grouped_training_names

fig_res = plot_residuals_by_energy(
    CKPT_DIR=CKPT_DIR,
    training_names=flatten_grouped_training_names(traning_names_grouped_omni),
    baseline_run=BASELINE_RUN,
    transform=lambda x: np.exp(x)-1
)
# Out:
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260301_012544 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_012542 on 1A
# No best model found for OmniM_SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260301_012539 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap2000000_Evts_seed_42_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap1000000_Evts_seed_42_1A_20260228_151916 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260228_151913 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_42_1A_20260228_151910 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_1A_20260228_151917 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap2000000_Evts_seed_42_1A_20260228_151916 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap1000000_Evts_seed_42_1A_20260228_151913 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260228_151911 on 1A
# No best model found for SmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260228_151908 on 1A
# Transforming the prediction
# E pred dict first 10 entries [ 2.1328917  1.2252753  1.4389567  0.8112726  0.768064  12.049016
#   2.7610075  2.6807294  0.3431723  0.9490807]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 51.366745
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.3511035   1.0964575   1.3131516   0.908316    0.75226104 12.00809
#   2.487356    2.2327569   0.32292533  0.93903124]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 6.234646e-05 47.767506
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.0749772   1.2362616   1.2929132   0.9312196   0.920097   10.852761
#   2.9278753   2.3231435   0.3040563   0.83571434]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 47.944263
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.2401872  1.2766871  1.4303708  1.2812648  1.0171349  9.127891
#  2.5055733  3.8491268  0.38534713 0.7528515 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.006026149 49.40815
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.2096198  1.1689022  1.1851327  1.2421024  0.52690566 7.82145
#  3.2694912  3.3903503  0.38097286 0.7133416 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 48.271523
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 1.7786846   2.1461878   1.1391027   0.93181336  0.6962347  10.313893
#   2.86879     3.2596216   0.33482647  0.9334216 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 172.38914
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.0479739   1.5998173   1.2019327   0.8768368   0.68222785 10.273436
#   2.3599901   2.9826317   0.32851708  1.0775006 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 50.082443
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.1456656   1.6178453   1.261414    1.1493087   0.82157385 10.040642
#   2.5934463   3.0856729   0.31516957  0.8943478 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 46.293064
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 1.927165    1.0024765   1.253555    1.5264876   0.80272365 10.274354
#   2.8856573   2.7266316   0.36904597  0.74590147]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 60.929173
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.0720725 1.0776412 1.3463356 1.2398701 0.5884998 9.029324  2.7340324
#  4.3877087 0.4247924 0.9461025]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 51.264782
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.1457322   1.3571007   1.5149496   1.0836961   0.5743786  12.544759
#   2.7743068   3.398192    0.34493637  0.93906593]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.025932074 50.814632
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [2.1421306  1.1283238  1.2064312  1.0529354  0.70877445 9.267948
#  2.440315   3.186335   0.34490383 1.0938616 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 48.60999
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.167749    1.2610009   1.2917881   1.1010957   0.68354666 10.025343
#   2.633827    2.6782598   0.30769563  0.95099306]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.04857397 48.967957
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [ 2.307078    1.365999    1.353472    1.2585714   0.7005459  10.151405
#   2.5349414   3.0537114   0.41356587  0.9122894 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.029037595 48.18522
# E true dict min max 0.0 77.44185
# Transforming the prediction
# E pred dict first 10 entries [1.6771727  1.5492458  1.3677659  1.0949624  0.7900934  7.2600317
#  2.680091   5.1212316  0.38108099 0.8320092 ]
# E true dict first 10 entries [ 5.0859704   2.857478    1.6605753   0.72240794  1.3871549  10.869374
#   0.9696065   4.78254     0.          1.0759095 ]
# E pred dict min max 0.0 62.179977
# E true dict min max 0.0 77.44185

# %%
fig_res = plot_residuals_by_energy(
    CKPT_DIR=CKPT_DIR,
    training_names=flatten_grouped_training_names(training_names_grouped),
    baseline_run=BASELINE_RUN,
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1PLoss_20260228_155407 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426 on playlist 1A
