# %%
from pathlib import Path
from eval_E_available_plots import load_eval_data_grouped, plot_rms_iqr_with_uncertainty

CKPT_DIR = Path("/global/cfs/cdirs/m3246/gregork/checkpoints")

BASELINE_RUN = "E_avail_no_muon_Log1pMSE_20260228_024020"

# Structure: loss -> "Architecture N_samples" -> [run_seed_1, run_seed_2, ...]
training_names_grouped = {"Log1p": {}}

training_names_grouped["Log1p"]["Transformer 6M"] = [
    "E_avail_no_muon_Log1pMSE_20260228_024020",
    "E_avail_Log1PLoss_20260228_155407",
]

#training_names_grouped["Log1p"]["Transformer 2M"] = [
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_42_20260227_204429",
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_43_20260227_205634",
#    "SmallDataset_E_avail_Log1PLoss_2000000_Evts_seed_44_20260227_205634",
#]

#training_names_grouped["Log1p"]["Transformer 1M"] = [
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_42_20260227_203125",
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_43_20260227_203126",
#    "SmallDataset_E_avail_Log1PLoss_1000000_Evts_seed_44_20260227_204430",
#]

training_names_grouped["Log1p"]["Transformer 500k"] = [
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516",
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619",
    "SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846",
]

training_names_grouped["Log1p"]["Transformer 100k"] = [
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544",
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544",
    "SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426",
]


training_names_grouped["Log1p"]["Transformer 50k"] = [
    "SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_43_20260301_120239",
    "SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_44_20260301_120233",
    "SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_42_20260301_120230",
]


data = load_eval_data_grouped(CKPT_DIR, training_names_grouped, baseline_run=BASELINE_RUN)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1PLoss_20260228_155407 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_43_20260301_120239 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_44_20260301_120233 on playlist 1A
# ...

# %%
sample_colors = {
    "6M":   "#1b9e77",
    "2M":   "#d95f02",
    "1M":   "#7570b3",
    "500k": "#e7298a",
    "100k": "#66a61e",
}

fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=training_names_grouped,
    baseline_run=BASELINE_RUN,
    colors=sample_colors,
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1PLoss_20260228_155407 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_43_20260301_120239 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_44_20260301_120233 on playlist 1A
# ...

# %%
# Make a quick IQR vs q3 plot of  E_avail_no_muon_Log1pMSE_20260228_024020 (Transformer), E_avail_Log1pLoss_ZeroRecoils_GlobalSums_20260305_000847 (Transformer-NoERecoil), E_avail_Log1pLoss_ZeroRecoilCCinc_GlobalSums_20260305_000443 (Transformer-NoERecoil-CCinc)

tmp_training_names = {
    "Log1p": {
        "Transformer": ["E_avail_no_muon_Log1pMSE_20260228_024020"],
        "Transformer-NoERecoil": ["E_avail_Log1pLoss_ZeroRecoils_GlobalSums_20260305_000847"],
        "Transformer-NoERecoil-CCinc": ["E_avail_Log1pLoss_ZeroRecoilCCinc_GlobalSums_20260305_000443"],
    }
}

clrs = { # distinct colors — most specific keys first (substring matching)
    "Transformer-NoERecoil-CCinc": "#0000ff",
    "Transformer-NoERecoil": "#ff0000",
    "Transformer": "#1b9e77",
}
fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=tmp_training_names,
    baseline_run=BASELINE_RUN,
    colors=clrs,
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1pLoss_ZeroRecoils_GlobalSums_20260305_000847 on playlist 1A
# No settings found for E_avail_Log1pLoss_ZeroRecoilCCinc_GlobalSums_20260305_000443 on playlist 1A
#   baseline: RMS = [0.13220823780103283, 0.15613262897682925, 0.20708822416474687, 0.2616824842730851, 0.29372826580799394], IQR = [0.1086998904198202, 0.15434651093745289, 0.2568240154904879, 0.4447950258298018, 0.6622872987786923]
# E_pred_dict keys for '1A': {'Log1p': ['Transformer§0', 'Transformer-NoERecoil§0', 'Transformer-NoERecoil-CCinc§0']}
#   Transformer (Log1p):
#     RMS = [0.1328737586736679, 0.1475428193807602, 0.1856953203678131, 0.24091531336307526, 0.2829250693321228]
#     IQR = [0.08181354403495789, 0.1292700171470642, 0.21281664073467255, 0.34909993410110474, 0.5303820967674255]
#   Transformer-NoERecoil (Log1p):
# ...

# %%
training_names_omni_list = """OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443
FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300
FullDataset_E_avail_Log1PLoss_1A_20260301_230852"""

traning_names_grouped_omni = {"Log1p": {}}

# OmniLearned pretrained
traning_names_grouped_omni["Log1p"]["OmniS 6M"] = [
    "FullDataset_E_avail_Log1PLoss_1A_20260301_230852",
    "E_avail_Log1PLoss_1A_20260308_120335"
]

traning_names_grouped_omni["Log1p"]["OmniS PT 6M"] = [
    "FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300",
    "E_avail_Log1PLoss_PT_1A_20260308_120208",
    "E_avail_Log1PLoss_PT_1A_20260308_120206"
]

traning_names_grouped_omni["Log1p"]["OmniM PT 6M"] = [
    "OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443",
    "OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260306_185733",
    "E_avail_Log1PLoss_PT_M_1A_20260308_120221"
]

traning_names_grouped_omni["Log1p"]["Transformer 6M"] = [
    "E_avail_no_muon_Log1pMSE_20260228_024020",
]

# Add these runs to training_names_grouped_omni



training_names_grouped_only_PT = {"Log1p": {}}

training_names_grouped_only_PT["Log1p"]["OmniS 500k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_44_1A_20260302_013720",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_43_1A_20260301_203335",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260301_203332",
]
training_names_grouped_only_PT["Log1p"]["OmniS PT 500k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_44_1A_20260302_013720",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_43_1A_20260301_203332",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_203332",
]

# 100k
training_names_grouped_only_PT["Log1p"]["OmniS 100k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_44_1A_20260302_013719",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_43_1A_20260301_203332",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_42_1A_20260301_203331",
]
training_names_grouped_only_PT["Log1p"]["OmniS PT 100k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_43_1A_20260301_203332",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260301_203331",
]

# 50k
training_names_grouped_only_PT["Log1p"]["OmniS 50k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap50000_Evts_seed_44_1A_20260302_013719",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap50000_Evts_seed_43_1A_20260301_203331",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap50000_Evts_seed_42_1A_20260301_203331",
]

training_names_grouped_only_PT["Log1p"]["OmniS PT 50k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_44_1A_20260302_013719",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_43_1A_20260301_203331",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_42_1A_20260301_203330",
]

# all of these are omniM

training_names_grouped_only_PT["Log1p"]["OmniM PT 500k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_44_1A_20260306_002726",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_43_1A_20260306_002723",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260306_002722",
]
training_names_grouped_only_PT["Log1p"]["OmniM PT 100k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_44_1A_20260306_002720",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_43_1A_20260306_002718",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap100000_Evts_seed_42_1A_20260306_002717",
]
training_names_grouped_only_PT["Log1p"]["OmniM PT 50k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_44_1A_20260306_002715",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_43_1A_20260306_002713",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap50000_Evts_seed_42_1A_20260306_002711",
]
training_names_grouped_only_PT["Log1p"]["OmniM PT 10k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap10000_Evts_seed_44_1A_20260306_002708",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap10000_Evts_seed_43_1A_20260306_002707",
    "FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap10000_Evts_seed_42_1A_20260306_002705",
]
training_names_grouped_only_PT["Log1p"]["OmniM 10k"] = [
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap10000_Evts_seed_44_1A_20260306_002558",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap10000_Evts_seed_43_1A_20260306_002556",
    "FixBugSmallDataset_E_avail_Log1PLoss_dscap10000_Evts_seed_42_1A_20260306_002553",
]


all_training_names = {
    loss: {**training_names_grouped.get(loss, {}), **traning_names_grouped_omni.get(loss, {})}
    for loss in set(training_names_grouped) | set(traning_names_grouped_omni)
}

# %%
# Generate training cmds
def eval_commands(trainings):
    for loss in trainings.keys():
        for model in trainings[loss].keys():
            for i in range(len(trainings[loss][model])):
                if "omni" in model.lower():
                    print(f"omnilearned evaluate -i {CKPT_DIR}/{trainings[loss][model][i]} --num-workers 2 --batch 100")
                else:
                    print(f"python -m src.scripts.eval --checkpoint {CKPT_DIR}/{trainings[loss][model][i]} --batch_size 1024 --dataset_name minerva_1A --no_amp")
print("")
eval_commands(traning_names_grouped_omni)
# Out:
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/FullDataset_E_avail_Log1PLoss_1A_20260301_230852 --num-workers 2 --batch 100
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/E_avail_Log1PLoss_1A_20260308_120335 --num-workers 2 --batch 100
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300 --num-workers 2 --batch 100
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/E_avail_Log1PLoss_PT_1A_20260308_120208 --num-workers 2 --batch 100
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/E_avail_Log1PLoss_PT_1A_20260308_120206 --num-workers 2 --batch 100
# omnilearned evaluate -i /global/cfs/cdirs/m3246/gregork/checkpoints/OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443 --num-workers 2 --batch 100
# ...

# %%
# plot here 
import numpy as np
clrs = {
    "OmniS 6M": "#1b9e77",
    "OmniS PT 6M": "#d95f02",
    "OmniM PT 6M": "#7570b3",
    "Transformer 6M": "#e7298a",
}
fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=traning_names_grouped_omni,
    baseline_run=BASELINE_RUN,
    colors=clrs,
    transform=None
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No best model found for FullDataset_E_avail_Log1PLoss_1A_20260301_230852 on 1A
# No best model found for E_avail_Log1PLoss_1A_20260308_120335 on 1A
# No best model found for FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120208 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120206 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260306_185733 on 1A
# No best model found for E_avail_Log1PLoss_PT_M_1A_20260308_120221 on 1A
#   baseline: RMS = [0.13220823780103283, 0.15613262897682925, 0.20708822416474687, 0.2616824842730851, 0.29372826580799394], IQR = [0.1086998904198202, 0.15434651093745289, 0.2568240154904879, 0.4447950258298018, 0.6622872987786923]
# ...

# %%
clrs = {
    "OmniS 500k": "#1b9e77",
    "OmniS PT 500k": "#d95f02",
    "OmniS 100k": "#7570b3",
    "OmniS PT 100k": "#e7298a",
    "OmniS 50k": "#1b9e77",
    "OmniS PT 50k": "#d95f02",
}
fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=training_names_grouped_only_PT,
    baseline_run=BASELINE_RUN,
    colors=clrs,
    transform=None
)
# Out:
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_44_1A_20260302_013720 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_43_1A_20260301_203335 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_dscap500000_Evts_seed_42_1A_20260301_203332 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_44_1A_20260302_013720 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_43_1A_20260301_203332 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_PT_dscap500000_Evts_seed_42_1A_20260301_203332 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_44_1A_20260302_013719 on 1A
# No best model found for FixBugSmallDataset_E_avail_Log1PLoss_dscap100000_Evts_seed_43_1A_20260301_203332 on 1A
# ...

# %%
# Now make the plot with all the data (omnilearned and transformer). 

from copy import copy
all_training_names = copy(traning_names_grouped_omni)

#all_data = load_eval_data_grouped(CKPT_DIR, all_training_names, baseline_run=BASELINE_RUN)
# Only add the transformer with full dataset to all_training_names
all_training_names["Log1p"]["Transformer 6M"] = [
    "E_avail_no_muon_Log1pMSE_20260228_024020",
]

clrs = {
    "OmniS 6M": "#1b9e77",
    "OmniS PT 6M": "#d95f02",
    "OmniM 6M": "#7570b3",
    "Transformer 6M": "#e7298a",
}

fig = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=all_training_names,
    baseline_run=BASELINE_RUN,
    colors=clrs,
    transform=None,
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No best model found for FullDataset_E_avail_Log1PLoss_1A_20260301_230852 on 1A
# No best model found for E_avail_Log1PLoss_1A_20260308_120335 on 1A
# No best model found for FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120208 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120206 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260306_185733 on 1A
# No best model found for E_avail_Log1PLoss_PT_M_1A_20260308_120221 on 1A
#   baseline: RMS = [0.13220823780103283, 0.15613262897682925, 0.20708822416474687, 0.2616824842730851, 0.29372826580799394], IQR = [0.1086998904198202, 0.15434651093745289, 0.2568240154904879, 0.4447950258298018, 0.6622872987786923]
# ...

# %%
from eval_E_available_plots import plot_residuals_by_energy, flatten_grouped_training_names

fig_res = plot_residuals_by_energy(
    CKPT_DIR=CKPT_DIR,
    training_names=flatten_grouped_training_names(traning_names_grouped_omni),
    baseline_run=BASELINE_RUN,
    transform=None
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No best model found for FullDataset_E_avail_Log1PLoss_1A_20260301_230852 on 1A
# No best model found for E_avail_Log1PLoss_1A_20260308_120335 on 1A
# No best model found for FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120208 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120206 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260306_185733 on 1A
# No best model found for E_avail_Log1PLoss_PT_M_1A_20260308_120221 on 1A

# %%
fig_res = plot_residuals_by_energy(
    CKPT_DIR=CKPT_DIR,
    training_names=flatten_grouped_training_names(traning_names_grouped_omni),
    baseline_run=BASELINE_RUN,
)
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No best model found for FullDataset_E_avail_Log1PLoss_1A_20260301_230852 on 1A
# No best model found for E_avail_Log1PLoss_1A_20260308_120335 on 1A
# No best model found for FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231300 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120208 on 1A
# No best model found for E_avail_Log1PLoss_PT_1A_20260308_120206 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260301_231443 on 1A
# No best model found for OmniM_FullDataset_E_avail_Log1PLoss_PT_1A_20260306_185733 on 1A
# No best model found for E_avail_Log1PLoss_PT_M_1A_20260308_120221 on 1A

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
from eval_E_available_plots import plot_rms_iqr_with_uncertainty

# --- Combine all training names across cells into one dict ---
scaling_names = {"Log1p": {}}

for key in ["Transformer 6M", "Transformer 500k", "Transformer 100k", "Transformer 50k"]:
    scaling_names["Log1p"][key] = training_names_grouped["Log1p"][key]

for key in ["OmniS 6M", "OmniS PT 6M", "OmniM PT 6M"]:
    scaling_names["Log1p"][key] = traning_names_grouped_omni["Log1p"][key]

for key in ["OmniS 500k", "OmniS PT 500k", "OmniS 100k", "OmniS PT 100k",
            "OmniS 50k", "OmniS PT 50k", "OmniM PT 500k", "OmniM PT 100k",
            "OmniM PT 50k"]:
    scaling_names["Log1p"][key] = training_names_grouped_only_PT["Log1p"][key]

# Compute IQR / RMS values for all models via existing function
_, values = plot_rms_iqr_with_uncertainty(
    CKPT_DIR=CKPT_DIR,
    training_names_grouped=scaling_names,
    baseline_run=BASELINE_RUN,
    transform=None,
    return_values=True,
)
plt.close()

# --- IQR vs Number of Training Samples ---
Q3_BIN_IDX = 2

def _n_samples(label):
    m = re.search(r"(\d+(?:\.\d+)?)\s*([kKmM])\b", label)
    if m:
        return float(m.group(1)) * (1e6 if m.group(2).upper() == "M" else 1e3)
    return 0.0

def _method(label):
    return re.sub(r"\s+\d+(?:\.\d+)?[kKmM]$", "", label)

methods: dict[str, list[tuple[float, float, float]]] = {}
for loss in values:
    if loss in ("q3_bin_mids", "baseline"):
        continue
    for cfg, v in values[loss].items():
        methods.setdefault(_method(cfg), []).append(
            (_n_samples(cfg), v["iqr_mean"][Q3_BIN_IDX], v["iqr_std"][Q3_BIN_IDX])
        )

for m in methods:
    methods[m].sort()

method_style = {
    "OmniS":       {"color": "#1b9e77", "linestyle": "-"},
    "OmniS PT":    {"color": "#1b9e77", "linestyle": "--"},
    "OmniM PT":    {"color": "#7570b3", "linestyle": "--"},
    "Transformer": {"color": "#e7298a", "linestyle": "-"},
}

fig, ax = plt.subplots(figsize=(7, 5))
for method, pts in methods.items():
    xs, ys, yerrs = zip(*pts)
    style = method_style.get(method, {"color": "tab:gray", "linestyle": "-"})
    ax.errorbar(xs, ys, yerr=yerrs, marker="o", capsize=4, label=method, **style)

if "baseline" in values:
    ax.axhline(values["baseline"]["iqr"][Q3_BIN_IDX],
               color="black", linestyle=":", lw=1, label="baseline (E_recoil_CCinc)")

ax.set_xscale("log")
ax.set_xlabel("Number of training samples")
ax.set_ylabel(f"IQR [GeV]")
q3_mid = values["q3_bin_mids"][Q3_BIN_IDX]
ax.set_title(f"IQR vs Training Samples (q$_3$ bin {Q3_BIN_IDX}, mid = {q3_mid:.2f} GeV)")
ax.legend(fontsize=9)
ax.grid(True)

fig.tight_layout()
fig.show()
# Out:
# No settings found for E_avail_no_muon_Log1pMSE_20260228_024020 on playlist 1A
# No settings found for E_avail_Log1PLoss_20260228_155407 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_42_20260227_194516 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_43_20260227_200619 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_500000_Evts_seed_44_20260227_200846 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_42_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_43_20260227_191544 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_100000_Evts_seed_44_20260227_194426 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_43_20260301_120239 on playlist 1A
# No settings found for SmallDataset_E_avail_Log1PLoss_50000_Evts_seed_44_20260301_120233 on playlist 1A
# ...
