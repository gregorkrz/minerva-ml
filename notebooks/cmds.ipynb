# %%
# import generate_cmd from src.jobs.submit_train_jobs
import os
# add src to python path
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))
if str(ROOT / "notebooks") not in sys.path:
    sys.path.insert(0, str(ROOT / "notebooks"))

from src.jobs.submit_train_jobs import generate_cmd

# %%
print(generate_cmd(data_cap=-1, seed=42, task="regression", model="Transformer1", bs=2048, max_steps=500000, grad_accum_steps=1, continue_from=""))
# Out:
# python -m src.scripts.train -bs 2048 --mode regression -E-available-no-muon -name Run_1203_regression_Transformer1_data_cap_-1_seed_42 --d_model 128 --depth 4 --n_heads 8 --dropout 0.0 --attn_dropout 0.0  --seed 42 -seed-event-sampler 42  --max_steps 500000 --grad_accum_steps 1
