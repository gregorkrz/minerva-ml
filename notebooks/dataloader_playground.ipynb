# %%
# include the parent dir into pythonpath
import sys
sys.path.append('..')

from src.dataset.dataloader import load_data, HEPTorchDataset
from time import time

dataloader, class_weights = load_data("minerva_1A", "/global/cfs/cdirs/m3246/gregork/Minerva/20260201_all_max_blobs_and_prongs_split_fix_anomalies", batch=1024, dataset_type="train", mode="regression", distributed=False, classification_event_type=False)

sample = next(iter(dataloader))
# Out:
# Number of events per file [6080324]
# Number of events per file [6080324]
# Number of events per file [6080324]
# Number of events per file [6080324]

# %%
sample.keys()
# Out:
# dict_keys(['X', 'y', 'attention_mask', 'cond', 'pid', 'add_info', 'data_pid', 'vertex_pid'])

# %%
sample["y"]
# Out:
# tensor([2, 2, 2,  ..., 1, 2, 2])

# %%
sample["X"][0].shape
# Out:
# torch.Size([33, 5])

# %%
len(dataloader)
# Out:
# Number of events per file [6080324]
# 5938
